# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output/example.txt")
df.head(5)
# Out:
#    iter  fitness
# 0     0        7
# 1     0       22
# 2     0       18
# 3     0       16
# 4     0       17

# %%
mean = df.groupby("iter").mean()
std = df.groupby("iter").std()
mean.plot(figsize=(20, 5))
plt.grid(True)
